# %%
import torch

print(torch.__version__)
print(torch.version.cuda)
# Out:
# 2.2.2+cu118
# 11.8

# %%
hate_speech_detection/
│
├── config/
│   └── config.yaml                 # Cấu hình chung
│
├── data/
│   ├── raw/                        # Dữ liệu thô
│   ├── processed/                  # Dữ liệu đã xử lý
│   └── dictionaries/               # Từ điển
│       ├── teencode_map.yaml
│       ├── profanity_words.yaml
│       ├── emoticon_map.yaml
│       └── leetspeak_map.yaml
│
├── src/
│   ├── __init__.py
│   ├── pipeline/
│   │   ├── __init__.py
│   │   ├── step1_unicode_normalizer.py
│   │   ├── step2_placeholder_handler.py
│   │   ├── step3_evasion_handler.py
│   │   ├── step4_elongation_handler.py
│   │   ├── step5_emoji_handler.py
│   │   ├── step6_teencode_handler.py
│   │   ├── step7_negation_handler.py
│   │   ├── step8_word_segmenter.py
│   │   └── master_pipeline.py
│   │
│   ├── models/
│   │   ├── __init__.py
│   │   ├── baseline_model.py
│   │   └── phobert_model.py
│   │
│   └── evaluation/
│       ├── __init__.py
│       └── evaluator.py
│
├── tests/
│   └──text_test.txt
│   
├── models_best/                # Nơi chứa các mô hình đã đc train
│   
│
├── notebooks/
│   └── exploration.ipynb
│
├── requirements.txt
└── main.py
